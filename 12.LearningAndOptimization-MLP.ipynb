# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import SGD, Adam, RMSprop

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

num_classes = 10

def create_model(learning_rate, optimizer):
    model = Sequential([
        Flatten(input_shape=(32, 32, 3)),
        Dense(512, activation='relu'),
        Dense(256, activation='relu'),
        Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer=optimizer(learning_rate=learning_rate),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

def train_model(model, x_train, y_train, x_test, y_test, epochs=10, batch_size=32):
    history = model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size,
                        validation_data=(x_test, y_test))
    return history.history

learning_rates = [0.001, 0.01, 0.1]
optimizers = {'SGD': SGD, 'Adam': Adam, 'RMSprop': RMSprop}
epochs = 10
batch_size = 32

results = {}

for optimizer_name, optimizer_class in optimizers.items():
    for lr in learning_rates:
        model = create_model(lr, optimizer_class)
        print(f"\nTraining model with optimizer: {optimizer_name}, learning rate: {lr}")
        history = train_model(model, x_train, y_train, x_test, y_test, epochs, batch_size)
        results[(optimizer_name, lr)] = history

for (optimizer_name, lr), history in results.items():
    print(f"\nOptimizer: {optimizer_name}, Learning Rate: {lr}")
    print("Training Accuracy:", history['accuracy'])
    print("Validation Accuracy:", history['val_accuracy'])

training_accs = [history['accuracy'][-1] for history in results.values()]
validation_accs = [history['val_accuracy'][-1] for history in results.values()]

avg_training_acc = sum(training_accs) / len(training_accs)
avg_validation_acc = sum(validation_accs) / len(validation_accs)

generalization_gap = avg_training_acc - avg_validation_acc

print("\nAverage Training Accuracy:", avg_training_acc)
print("Average Validation Accuracy:", avg_validation_acc)
print("Generalization Gap:", generalization_gap)
# Out:
# C:\Users\Sakuntala\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Training model with optimizer: SGD, learning rate: 0.001
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.2269 - loss: 2.1444 - val_accuracy: 0.3216 - val_loss: 1.9293
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.3353 - loss: 1.9046 - val_accuracy: 0.3554 - val_loss: 1.8464
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.3572 - loss: 1.8458 - val_accuracy: 0.3630 - val_loss: 1.8057
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.3738 - loss: 1.7950 - val_accuracy: 0.3836 - val_loss: 1.7672
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.3884 - loss: 1.7559 - val_accuracy: 0.3976 - val_loss: 1.7456
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.3986 - loss: 1.7335 - val_accuracy: 0.4014 - val_loss: 1.7188
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.4107 - loss: 1.7015 - val_accuracy: 0.4093 - val_loss: 1.6975
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.4164 - loss: 1.6836 - val_accuracy: 0.4132 - val_loss: 1.6784
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.4229 - loss: 1.6611 - val_accuracy: 0.4179 - val_loss: 1.6625
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.4268 - loss: 1.6470 - val_accuracy: 0.4253 - val_loss: 1.6509
#
# Training model with optimizer: SGD, learning rate: 0.01
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.2886 - loss: 1.9672 - val_accuracy: 0.3812 - val_loss: 1.7482
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.4034 - loss: 1.6900 - val_accuracy: 0.4056 - val_loss: 1.6749
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.4304 - loss: 1.6077 - val_accuracy: 0.4282 - val_loss: 1.6055
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.4561 - loss: 1.5378 - val_accuracy: 0.4479 - val_loss: 1.5542
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.4719 - loss: 1.4956 - val_accuracy: 0.4675 - val_loss: 1.5015
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.4857 - loss: 1.4500 - val_accuracy: 0.4596 - val_loss: 1.5229
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.4998 - loss: 1.4156 - val_accuracy: 0.4813 - val_loss: 1.4527
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.5110 - loss: 1.3826 - val_accuracy: 0.4819 - val_loss: 1.4369
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.5240 - loss: 1.3507 - val_accuracy: 0.4539 - val_loss: 1.5132
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.5290 - loss: 1.3337 - val_accuracy: 0.4901 - val_loss: 1.4263
#
# Training model with optimizer: SGD, learning rate: 0.1
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.2534 - loss: 2.0699 - val_accuracy: 0.3118 - val_loss: 1.9012
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.3755 - loss: 1.7376 - val_accuracy: 0.3548 - val_loss: 1.8190
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.4053 - loss: 1.6474 - val_accuracy: 0.3795 - val_loss: 1.6770
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.4357 - loss: 1.5781 - val_accuracy: 0.4356 - val_loss: 1.5659
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.4496 - loss: 1.5367 - val_accuracy: 0.4104 - val_loss: 1.6635
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.4605 - loss: 1.4988 - val_accuracy: 0.4568 - val_loss: 1.5455
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.4770 - loss: 1.4628 - val_accuracy: 0.4647 - val_loss: 1.5076
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.4859 - loss: 1.4340 - val_accuracy: 0.4451 - val_loss: 1.5611
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.4944 - loss: 1.4124 - val_accuracy: 0.4675 - val_loss: 1.4982
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.5016 - loss: 1.3843 - val_accuracy: 0.4733 - val_loss: 1.5045
#
# Training model with optimizer: Adam, learning rate: 0.001
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 15ms/step - accuracy: 0.2840 - loss: 2.0001 - val_accuracy: 0.4054 - val_loss: 1.6674
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 15ms/step - accuracy: 0.3897 - loss: 1.6894 - val_accuracy: 0.3880 - val_loss: 1.6656
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 15ms/step - accuracy: 0.4234 - loss: 1.6091 - val_accuracy: 0.4120 - val_loss: 1.6195
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 16ms/step - accuracy: 0.4433 - loss: 1.5470 - val_accuracy: 0.4600 - val_loss: 1.5207
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 15ms/step - accuracy: 0.4577 - loss: 1.5098 - val_accuracy: 0.4531 - val_loss: 1.5512
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 15ms/step - accuracy: 0.4700 - loss: 1.4848 - val_accuracy: 0.4816 - val_loss: 1.4683
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 15ms/step - accuracy: 0.4832 - loss: 1.4507 - val_accuracy: 0.4694 - val_loss: 1.4797
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 15ms/step - accuracy: 0.4912 - loss: 1.4280 - val_accuracy: 0.4734 - val_loss: 1.4730
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.4929 - loss: 1.4142 - val_accuracy: 0.4766 - val_loss: 1.4638
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.5124 - loss: 1.3763 - val_accuracy: 0.4774 - val_loss: 1.4753
#
# Training model with optimizer: Adam, learning rate: 0.01
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 25s 16ms/step - accuracy: 0.1753 - loss: 3.3985 - val_accuracy: 0.2513 - val_loss: 1.9815
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 27s 17ms/step - accuracy: 0.2479 - loss: 1.9817 - val_accuracy: 0.2529 - val_loss: 1.9414
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 25s 16ms/step - accuracy: 0.2482 - loss: 1.9702 - val_accuracy: 0.2342 - val_loss: 1.9603
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 25s 16ms/step - accuracy: 0.2436 - loss: 1.9719 - val_accuracy: 0.2470 - val_loss: 1.9428
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 25s 16ms/step - accuracy: 0.2503 - loss: 1.9579 - val_accuracy: 0.2524 - val_loss: 1.9366
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 25s 16ms/step - accuracy: 0.2497 - loss: 1.9579 - val_accuracy: 0.2475 - val_loss: 1.9596
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 147s 94ms/step - accuracy: 0.2424 - loss: 1.9739 - val_accuracy: 0.2623 - val_loss: 1.9436
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 25s 16ms/step - accuracy: 0.2507 - loss: 1.9558 - val_accuracy: 0.2524 - val_loss: 1.9227
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.2466 - loss: 1.9524 - val_accuracy: 0.2654 - val_loss: 1.9143
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.2545 - loss: 1.9557 - val_accuracy: 0.2675 - val_loss: 1.9179
#
# Training model with optimizer: Adam, learning rate: 0.1
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 25s 16ms/step - accuracy: 0.0998 - loss: 98.3553 - val_accuracy: 0.1000 - val_loss: 2.3147
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 41s 16ms/step - accuracy: 0.0956 - loss: 2.3149 - val_accuracy: 0.1000 - val_loss: 2.3138
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.0989 - loss: 2.3152 - val_accuracy: 0.1000 - val_loss: 2.3098
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 446s 286ms/step - accuracy: 0.0976 - loss: 2.3140 - val_accuracy: 0.1000 - val_loss: 2.3116
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.0980 - loss: 2.3157 - val_accuracy: 0.1000 - val_loss: 2.3083
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 25s 16ms/step - accuracy: 0.0992 - loss: 2.3148 - val_accuracy: 0.1000 - val_loss: 2.3148
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 25s 16ms/step - accuracy: 0.1025 - loss: 2.3168 - val_accuracy: 0.1000 - val_loss: 2.3264
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 25s 16ms/step - accuracy: 0.0994 - loss: 2.3150 - val_accuracy: 0.1000 - val_loss: 2.3174
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 25s 16ms/step - accuracy: 0.1020 - loss: 2.3153 - val_accuracy: 0.1000 - val_loss: 2.3195
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 25s 16ms/step - accuracy: 0.1005 - loss: 2.3154 - val_accuracy: 0.1000 - val_loss: 2.3200
#
# Training model with optimizer: RMSprop, learning rate: 0.001
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.2542 - loss: 2.1993 - val_accuracy: 0.2770 - val_loss: 2.2336
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.3877 - loss: 1.7210 - val_accuracy: 0.4197 - val_loss: 1.6680
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.4239 - loss: 1.6251 - val_accuracy: 0.4177 - val_loss: 1.6332
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.4385 - loss: 1.5816 - val_accuracy: 0.4386 - val_loss: 1.5810
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.4493 - loss: 1.5563 - val_accuracy: 0.4334 - val_loss: 1.5728
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.4532 - loss: 1.5337 - val_accuracy: 0.4686 - val_loss: 1.5235
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.4631 - loss: 1.5239 - val_accuracy: 0.3775 - val_loss: 1.7993
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.4642 - loss: 1.5134 - val_accuracy: 0.4453 - val_loss: 1.5926
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.4664 - loss: 1.5010 - val_accuracy: 0.4393 - val_loss: 1.5971
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.4694 - loss: 1.5098 - val_accuracy: 0.4247 - val_loss: 1.7026
#
# Training model with optimizer: RMSprop, learning rate: 0.01
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 12ms/step - accuracy: 0.1005 - loss: 6.7411 - val_accuracy: 0.1000 - val_loss: 2.3037
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.1000 - loss: 2.3044 - val_accuracy: 0.1000 - val_loss: 2.3043
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.0986 - loss: 2.3083 - val_accuracy: 0.1003 - val_loss: 2.3035
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.1010 - loss: 2.3044 - val_accuracy: 0.1002 - val_loss: 2.3040
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.0962 - loss: 2.3043 - val_accuracy: 0.1003 - val_loss: 2.3027
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.1000 - loss: 2.3038 - val_accuracy: 0.1004 - val_loss: 2.3033
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.0986 - loss: 2.3036 - val_accuracy: 0.1003 - val_loss: 2.3032
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.0998 - loss: 2.3032 - val_accuracy: 0.1004 - val_loss: 2.3033
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.0971 - loss: 2.3031 - val_accuracy: 0.1002 - val_loss: 2.3042
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.1026 - loss: 2.3029 - val_accuracy: 0.1003 - val_loss: 2.3028
#
# Training model with optimizer: RMSprop, learning rate: 0.1
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 12ms/step - accuracy: 0.1027 - loss: 1431.1489 - val_accuracy: 0.1000 - val_loss: 2.3177
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.1016 - loss: 2.3901 - val_accuracy: 0.1000 - val_loss: 2.3117
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.0991 - loss: 2.3163 - val_accuracy: 0.1000 - val_loss: 2.3158
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.0974 - loss: 2.3164 - val_accuracy: 0.1000 - val_loss: 2.3117
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.1010 - loss: 2.3152 - val_accuracy: 0.1000 - val_loss: 2.3096
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.1010 - loss: 2.3157 - val_accuracy: 0.0999 - val_loss: 2.3174
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.1028 - loss: 2.3164 - val_accuracy: 0.1000 - val_loss: 2.3108
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.0975 - loss: 2.3166 - val_accuracy: 0.1000 - val_loss: 2.3116
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.1018 - loss: 2.3161 - val_accuracy: 0.1000 - val_loss: 2.3177
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.1034 - loss: 2.3158 - val_accuracy: 0.1000 - val_loss: 2.3103
#
# Optimizer: SGD, Learning Rate: 0.001
# Training Accuracy: [0.27261999249458313, 0.34318000078201294, 0.3646000027656555, 0.3789199888706207, 0.3907800018787384, 0.40097999572753906, 0.4079200029373169, 0.416920006275177, 0.422760009765625, 0.4267599880695343]
# Validation Accuracy: [0.3215999901294708, 0.3553999960422516, 0.3630000054836273, 0.38359999656677246, 0.397599995136261, 0.40139999985694885, 0.4092999994754791, 0.4131999909877777, 0.4178999960422516, 0.4253000020980835]
#
# Optimizer: SGD, Learning Rate: 0.01
# Training Accuracy: [0.3355399966239929, 0.40841999650001526, 0.4336000084877014, 0.4581800103187561, 0.4743799865245819, 0.4907799959182739, 0.5008599758148193, 0.512660026550293, 0.5217199921607971, 0.5287600159645081]
# Validation Accuracy: [0.38119998574256897, 0.40560001134872437, 0.42820000648498535, 0.4478999972343445, 0.4675000011920929, 0.4596000015735626, 0.4812999963760376, 0.48190000653266907, 0.453900009393692, 0.4900999963283539]
#
# Optimizer: SGD, Learning Rate: 0.1
# Training Accuracy: [0.3065199851989746, 0.3826799988746643, 0.4116800129413605, 0.4354400038719177, 0.44953998923301697, 0.46154001355171204, 0.4754999876022339, 0.48416000604629517, 0.49230000376701355, 0.5003200173377991]
# Validation Accuracy: [0.3118000030517578, 0.3547999858856201, 0.37950000166893005, 0.43560001254081726, 0.41040000319480896, 0.45680001378059387, 0.46470001339912415, 0.44510000944137573, 0.4675000011920929, 0.4733000099658966]
#
# Optimizer: Adam, Learning Rate: 0.001
# Training Accuracy: [0.328000009059906, 0.3993000090122223, 0.42932000756263733, 0.4468199908733368, 0.45899999141693115, 0.47426000237464905, 0.4799000024795532, 0.4902600049972534, 0.49553999304771423, 0.5038599967956543]
# Validation Accuracy: [0.40540000796318054, 0.3880000114440918, 0.41200000047683716, 0.46000000834465027, 0.4530999958515167, 0.48159998655319214, 0.46939998865127563, 0.4733999967575073, 0.4765999913215637, 0.477400004863739]
#
# Optimizer: Adam, Learning Rate: 0.01
# Training Accuracy: [0.20701999962329865, 0.247979998588562, 0.24607999622821808, 0.24305999279022217, 0.2463800013065338, 0.24835999310016632, 0.24305999279022217, 0.25082001090049744, 0.2477400004863739, 0.2526000142097473]
# Validation Accuracy: [0.25130000710487366, 0.25290000438690186, 0.23420000076293945, 0.24699999392032623, 0.2524000108242035, 0.2475000023841858, 0.2623000144958496, 0.2524000108242035, 0.2653999924659729, 0.26750001311302185]
#
# Optimizer: Adam, Learning Rate: 0.1
# Training Accuracy: [0.09882000088691711, 0.0995199978351593, 0.10100000351667404, 0.09956000000238419, 0.09777999669313431, 0.09796000272035599, 0.0993800014257431, 0.09956000000238419, 0.10181999951601028, 0.09994000196456909]
# Validation Accuracy: [0.10000000149011612, 0.10000000149011612, 0.10000000149011612, 0.10000000149011612, 0.10000000149011612, 0.10000000149011612, 0.10000000149011612, 0.10000000149011612, 0.10000000149011612, 0.10000000149011612]
#
# Optimizer: RMSprop, Learning Rate: 0.001
# Training Accuracy: [0.3111799955368042, 0.3948400020599365, 0.42333999276161194, 0.4391799867153168, 0.4485200047492981, 0.4560000002384186, 0.4640600085258484, 0.46230000257492065, 0.4651600122451782, 0.4666999876499176]
# Validation Accuracy: [0.2770000100135803, 0.4196999967098236, 0.41769999265670776, 0.43860000371932983, 0.4334000051021576, 0.46860000491142273, 0.3774999976158142, 0.44530001282691956, 0.439300000667572, 0.424699991941452]
#
# Optimizer: RMSprop, Learning Rate: 0.01
# Training Accuracy: [0.10171999782323837, 0.09991999715566635, 0.09960000216960907, 0.09969999641180038, 0.09799999743700027, 0.10050000250339508, 0.09798000007867813, 0.09888000041246414, 0.0993800014257431, 0.10074000060558319]
# Validation Accuracy: [0.10000000149011612, 0.10000000149011612, 0.10029999911785126, 0.10019999742507935, 0.10029999911785126, 0.10040000081062317, 0.10029999911785126, 0.10040000081062317, 0.10019999742507935, 0.10029999911785126]
#
# Optimizer: RMSprop, Learning Rate: 0.1
# Training Accuracy: [0.09969999641180038, 0.09895999729633331, 0.10029999911785126, 0.09796000272035599, 0.09932000190019608, 0.09995999932289124, 0.1011200025677681, 0.09758000075817108, 0.10022000223398209, 0.10189999639987946]
# Validation Accuracy: [0.10000000149011612, 0.10000000149011612, 0.10000000149011612, 0.10000000149011612, 0.10000000149011612, 0.09989999979734421, 0.10000000149011612, 0.10000000149011612, 0.10000000149011612, 0.10000000149011612]
#
# Average Training Accuracy: 0.3312866687774658
# Average Validation Accuracy: 0.31762222448984784
# Generalization Gap: 0.013664444287617983
