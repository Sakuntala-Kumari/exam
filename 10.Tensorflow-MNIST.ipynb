# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0

num_classes = 10

def create_model(hidden_layers, neurons_per_layer):
    model = Sequential()
    model.add(Flatten(input_shape=(28, 28))) 
    for _ in range(hidden_layers):
        model.add(Dense(neurons_per_layer, activation='relu'))  
    model.add(Dense(num_classes, activation='softmax'))  
    return model

def compile_and_train_model(model, x_train, y_train, x_test, y_test, epochs=5, batch_size=32):
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(x_test, y_test))

hidden_layers = [1, 2, 3]  
neurons_per_layer = [64, 128, 256]  

for layers in hidden_layers:
    for neurons in neurons_per_layer:
        print(f"\nExperimenting with {layers} hidden layers and {neurons} neurons per layer:")
        model = create_model(layers, neurons)
        compile_and_train_model(model, x_train, y_train, x_test, y_test)
# Out:
# Experimenting with 1 hidden layers and 64 neurons per layer:
# C:\Users\Sakuntala\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8578 - loss: 0.5017 - val_accuracy: 0.9497 - val_loss: 0.1723
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9526 - loss: 0.1596 - val_accuracy: 0.9613 - val_loss: 0.1288
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 941us/step - accuracy: 0.9668 - loss: 0.1114 - val_accuracy: 0.9691 - val_loss: 0.1089
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 908us/step - accuracy: 0.9739 - loss: 0.0865 - val_accuracy: 0.9710 - val_loss: 0.0980
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 899us/step - accuracy: 0.9778 - loss: 0.0701 - val_accuracy: 0.9748 - val_loss: 0.0876
#
# Experimenting with 1 hidden layers and 128 neurons per layer:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8781 - loss: 0.4317 - val_accuracy: 0.9603 - val_loss: 0.1353
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9658 - loss: 0.1204 - val_accuracy: 0.9667 - val_loss: 0.1059
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9784 - loss: 0.0755 - val_accuracy: 0.9748 - val_loss: 0.0791
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9839 - loss: 0.0543 - val_accuracy: 0.9735 - val_loss: 0.0808
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9879 - loss: 0.0415 - val_accuracy: 0.9747 - val_loss: 0.0802
#
# Experimenting with 1 hidden layers and 256 neurons per layer:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8904 - loss: 0.3868 - val_accuracy: 0.9643 - val_loss: 0.1154
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9703 - loss: 0.0967 - val_accuracy: 0.9684 - val_loss: 0.0984
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9806 - loss: 0.0619 - val_accuracy: 0.9760 - val_loss: 0.0782
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9877 - loss: 0.0408 - val_accuracy: 0.9771 - val_loss: 0.0756
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9906 - loss: 0.0302 - val_accuracy: 0.9781 - val_loss: 0.0696
#
# Experimenting with 2 hidden layers and 64 neurons per layer:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8584 - loss: 0.4873 - val_accuracy: 0.9546 - val_loss: 0.1526
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9606 - loss: 0.1338 - val_accuracy: 0.9685 - val_loss: 0.1061
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9715 - loss: 0.0927 - val_accuracy: 0.9722 - val_loss: 0.0981
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9782 - loss: 0.0728 - val_accuracy: 0.9721 - val_loss: 0.0945
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9829 - loss: 0.0550 - val_accuracy: 0.9734 - val_loss: 0.0969
#
# Experimenting with 2 hidden layers and 128 neurons per layer:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8834 - loss: 0.4023 - val_accuracy: 0.9649 - val_loss: 0.1086
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9675 - loss: 0.1025 - val_accuracy: 0.9732 - val_loss: 0.0868
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9782 - loss: 0.0681 - val_accuracy: 0.9730 - val_loss: 0.0821
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9857 - loss: 0.0470 - val_accuracy: 0.9764 - val_loss: 0.0733
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9887 - loss: 0.0357 - val_accuracy: 0.9785 - val_loss: 0.0776
#
# Experimenting with 2 hidden layers and 256 neurons per layer:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8933 - loss: 0.3539 - val_accuracy: 0.9650 - val_loss: 0.1124
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9724 - loss: 0.0882 - val_accuracy: 0.9732 - val_loss: 0.0829
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9812 - loss: 0.0591 - val_accuracy: 0.9743 - val_loss: 0.0838
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9863 - loss: 0.0434 - val_accuracy: 0.9769 - val_loss: 0.0764
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9895 - loss: 0.0321 - val_accuracy: 0.9744 - val_loss: 0.0870
#
# Experimenting with 3 hidden layers and 64 neurons per layer:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8477 - loss: 0.5022 - val_accuracy: 0.9496 - val_loss: 0.1614
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9593 - loss: 0.1352 - val_accuracy: 0.9686 - val_loss: 0.1015
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9704 - loss: 0.0934 - val_accuracy: 0.9702 - val_loss: 0.0960
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9766 - loss: 0.0738 - val_accuracy: 0.9693 - val_loss: 0.0972
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9814 - loss: 0.0592 - val_accuracy: 0.9705 - val_loss: 0.1016
#
# Experimenting with 3 hidden layers and 128 neurons per layer:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8812 - loss: 0.3973 - val_accuracy: 0.9635 - val_loss: 0.1180
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9670 - loss: 0.1028 - val_accuracy: 0.9693 - val_loss: 0.1012
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9787 - loss: 0.0672 - val_accuracy: 0.9659 - val_loss: 0.1119
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9848 - loss: 0.0510 - val_accuracy: 0.9701 - val_loss: 0.1042
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9859 - loss: 0.0436 - val_accuracy: 0.9726 - val_loss: 0.0952
#
# Experimenting with 3 hidden layers and 256 neurons per layer:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8999 - loss: 0.3385 - val_accuracy: 0.9596 - val_loss: 0.1270
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9713 - loss: 0.0943 - val_accuracy: 0.9677 - val_loss: 0.1159
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9794 - loss: 0.0658 - val_accuracy: 0.9764 - val_loss: 0.0786
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9839 - loss: 0.0523 - val_accuracy: 0.9751 - val_loss: 0.0919
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9880 - loss: 0.0381 - val_accuracy: 0.9797 - val_loss: 0.0703
